# %%
## space for importing required libraries
from sklearn.datasets import make_classification, make_circles #libraries to generate data
import matplotlib.pyplot as plt # importing library to plot
import numpy as np #numpy library for data manipulation and plotting

# %%
np.random.seed(4)
numPoints = 200
X, y = make_circles(n_samples=numPoints,
  factor=.5, noise=.05) #function to yield non circle data provided by sklearn
X = 10 * X

f, ax = plt.subplots(figsize=(8, 6)) #plotting data
ax.scatter(X[:,0],X[:,1], c=y, s=50,cmap="RdBu")
plt.show()

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=10,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))
#Couches intermédiaires
model.add(Dense(units=10,activation= 'sigmoid'))
#La couche de sortie, units vaut 2 mais activation softmax
model.add(Dense(units=2, activation='softmax'))


#Création du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  2 (2 classes)
sortie = to_categorical(y) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 1
# 1 >  1 0     vecteur (y_true) > matrice binaire (sortie)


#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 2ms/step - loss: 0.2712 - accuracy: 0.5000
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2638 - accuracy: 0.4750
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2565 - accuracy: 0.4650
# Epoch 4/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.5250
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.4950
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2510 - accuracy: 0.5000
# Epoch 7/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.5300
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.4900
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5300
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.5050
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.4600
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.4850
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2475 - accuracy: 0.5550
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.5600
# Epoch 15/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2497 - accuracy: 0.5150
# Epoch 16/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2474 - accuracy: 0.5150
# Epoch 17/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2466 - accuracy: 0.5300
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.5750
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.5450
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.5600
# Epoch 21/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2436 - accuracy: 0.5650
# Epoch 22/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2438 - accuracy: 0.5700
# Epoch 23/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2403 - accuracy: 0.5900
# Epoch 24/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.5700
# Epoch 25/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2423 - accuracy: 0.6150
# Epoch 26/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2404 - accuracy: 0.5750
# Epoch 27/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.6400
# Epoch 28/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2362 - accuracy: 0.6250
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2351 - accuracy: 0.6900
# Epoch 30/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2319 - accuracy: 0.6550
# Epoch 31/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2282 - accuracy: 0.6400
# Epoch 32/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2251 - accuracy: 0.7000
# Epoch 33/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2196 - accuracy: 0.7250
# Epoch 34/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2149 - accuracy: 0.6900
# Epoch 35/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2099 - accuracy: 0.6800
# Epoch 36/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2054 - accuracy: 0.7550
# Epoch 37/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1986 - accuracy: 0.7400
# Epoch 38/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1923 - accuracy: 0.7250
# Epoch 39/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1856 - accuracy: 0.7750
# Epoch 40/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1803 - accuracy: 0.8100
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1793 - accuracy: 0.7150
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1691 - accuracy: 0.7950
# Epoch 43/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1662 - accuracy: 0.8150
# Epoch 44/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1539 - accuracy: 0.8300
# Epoch 45/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1500 - accuracy: 0.8250
# Epoch 46/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.8450
# Epoch 47/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1223 - accuracy: 0.8450
# Epoch 48/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1002 - accuracy: 0.9750
# Epoch 49/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0870 - accuracy: 1.0000
# Epoch 50/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 1.0000
# Epoch 51/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0589 - accuracy: 1.0000
# Epoch 52/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 55/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 56/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 58/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 59/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 60/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 61/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 62/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 63/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 64/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 66/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 67/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 68/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 69/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 70/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 71/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 72/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 73/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 74/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 75/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 76/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 77/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 78/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 80/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 81/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 82/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 83/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 84/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 86/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 87/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 88/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 89/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 90/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 92/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 93/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 96/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 97/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 98/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 99/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 100/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, model, steps=250,alpha=0.2,seuil=0.51):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    steps = steps
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    #fig, ax = plt.subplots()
    for i in range(0,2): 
        #labels1= labels[:,i]
        #print(labels1)
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.2f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    #print(y)
    ax.scatter(X[:,0], X[:,1], c= y,lw=1,marker=".", s=50,cmap="RdBu")
    
    return fig, ax

plot_decision_boundary2(entree, sortie[:,0], model, alpha=0.2, seuil=0.5)
plot_decision_boundary2(entree, y, model, alpha=0.2,seuil = 0.6)
plot_decision_boundary2(entree, y, model, alpha=0.2,seuil = 0.9)
# Out:
# 1954/1954 [==============================] - 2s 874us/step
# 1954/1954 [==============================] - 2s 865us/step
# 1954/1954 [==============================] - 2s 930us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)
