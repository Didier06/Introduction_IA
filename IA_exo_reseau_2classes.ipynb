# %% [markdown]
# # Génération de 2 classes de points
# * NbbPoints - nombre total de points à générer.
# * Chaque point a 3 caractéristiques : x, y, et type de classe  (0 pour la première classe et 1 pour la deuxième).

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("2 classes de points", fontsize="small")
centers = [(-4, 2), (0, 0)] # centre des classes
# création des 2 classes  
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10) 
# X1 contient les coordonnées x,y de chaque popint et Y1 est la classe des points 0 : 1ère classe  et 1 2ème classe
#print(X1)
#print(Y1)

# Xe et Xs sont dans un premier temps les entrées et sorties du réseau 
Xe = X1[:,0] # entrée x
Xs = X1[:,1] # entrée y
#print(Xe)
#print()

# tracé des points sur le graphe avec  leur étiquette correspondante en couleur
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.show()

# %% [markdown]
# # Création du réseau séquentiel avec des fonctions d'activation identité (linéaire)

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape doit être égale à 1 + couche 3 neurones units = 3
model.add(Dense(units=1,input_shape=[1],activation= 'linear',kernel_initializer = my_init))
# créer ici votre réseau de neurones avec une couche et un neurone avec une entrée Xe et la sortie Xs
#model.add(Dense(units=1, activation='linear'))
#Création de l'optimiseur ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['mse'])
entree = Xe
sortie = Xs

#Entraînement du réseau 1000 passages (1000 époques)
model.fit(x=entree,y=sortie,epochs=100)

#Affichage des poids
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
prediction = model.predict(xe)

# on obtient une régression linéaire ! on n'a pas séparé les classes de 2 points !
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 3ms/step - loss: 18.8180 - mse: 18.8180
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 17.6050 - mse: 17.6050
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 16.4991 - mse: 16.4991
# Epoch 4/100
# 4/4 [==============================] - 0s 4ms/step - loss: 15.5011 - mse: 15.5011
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 14.4965 - mse: 14.4965
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 13.5463 - mse: 13.5463
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 12.6308 - mse: 12.6308
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 11.7973 - mse: 11.7973
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 10.9514 - mse: 10.9514
# Epoch 10/100
# 4/4 [==============================] - 0s 1ms/step - loss: 10.2502 - mse: 10.2502
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.5293 - mse: 9.5293
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.8615 - mse: 8.8615
# Epoch 13/100
# 4/4 [==============================] - 0s 6ms/step - loss: 8.2499 - mse: 8.2499
# Epoch 14/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.6932 - mse: 7.6932
# Epoch 15/100
# 4/4 [==============================] - 0s 3ms/step - loss: 7.1613 - mse: 7.1613
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 6.6248 - mse: 6.6248
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 6.1792 - mse: 6.1792
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 5.7501 - mse: 5.7501
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 5.3335 - mse: 5.3335
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.9792 - mse: 4.9792
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.6341 - mse: 4.6341
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.3414 - mse: 4.3414
# Epoch 23/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0529 - mse: 4.0529
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8055 - mse: 3.8055
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.5757 - mse: 3.5757
# Epoch 26/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.3758 - mse: 3.3758
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.1812 - mse: 3.1812
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.0124 - mse: 3.0124
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.8382 - mse: 2.8382
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6972 - mse: 2.6972
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5694 - mse: 2.5694
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4594 - mse: 2.4594
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3602 - mse: 2.3602
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2727 - mse: 2.2727
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1919 - mse: 2.1919
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1168 - mse: 2.1168
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0486 - mse: 2.0486
# Epoch 38/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9939 - mse: 1.9939
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9471 - mse: 1.9471
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8984 - mse: 1.8984
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8574 - mse: 1.8574
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8220 - mse: 1.8220
# Epoch 43/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.7887 - mse: 1.7887
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7607 - mse: 1.7607
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7335 - mse: 1.7335
# Epoch 46/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7074 - mse: 1.7074
# Epoch 47/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6838 - mse: 1.6838
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6629 - mse: 1.6629
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6412 - mse: 1.6412
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6249 - mse: 1.6249
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6102 - mse: 1.6102
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5956 - mse: 1.5956
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5826 - mse: 1.5826
# Epoch 54/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5700 - mse: 1.5700
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5574 - mse: 1.5574
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5455 - mse: 1.5455
# Epoch 57/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.5344 - mse: 1.5344
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5240 - mse: 1.5240
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5147 - mse: 1.5147
# Epoch 60/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.5047 - mse: 1.5047
# Epoch 61/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4949 - mse: 1.4949
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4859 - mse: 1.4859
# Epoch 63/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4767 - mse: 1.4767
# Epoch 64/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4694 - mse: 1.4694
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4617 - mse: 1.4617
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4548 - mse: 1.4548
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4478 - mse: 1.4478
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4406 - mse: 1.4406
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4350 - mse: 1.4350
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4286 - mse: 1.4286
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4228 - mse: 1.4228
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4185 - mse: 1.4185
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4138 - mse: 1.4138
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4093 - mse: 1.4093
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4051 - mse: 1.4051
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4003 - mse: 1.4003
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3961 - mse: 1.3961
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3924 - mse: 1.3924
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3887 - mse: 1.3887
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3850 - mse: 1.3850
# Epoch 81/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3822 - mse: 1.3822
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3788 - mse: 1.3788
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3753 - mse: 1.3753
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3712 - mse: 1.3712
# Epoch 85/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3675 - mse: 1.3675
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3636 - mse: 1.3636
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3597 - mse: 1.3597
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3565 - mse: 1.3565
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3538 - mse: 1.3538
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3510 - mse: 1.3510
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3475 - mse: 1.3475
# Epoch 92/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3440 - mse: 1.3440
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3417 - mse: 1.3417
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3374 - mse: 1.3374
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3348 - mse: 1.3348
# Epoch 96/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3323 - mse: 1.3323
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3305 - mse: 1.3305
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3287 - mse: 1.3287
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3268 - mse: 1.3268
# Epoch 100/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3256 - mse: 1.3256
#
# Weights:
#
# [array([[-0.32699803]], dtype=float32), array([0.5506563], dtype=float32)]
# 2/2 [==============================] - 0s 2ms/step

# %% [markdown]
# # Retraçons les points et le droite obtenue :

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("Two classes", fontsize="small")
centers = [(-4, 2), (0, 0)]
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10,center_box=(-10.0, 10.0))

Xe = X1[:,0]
Xs = X1[:,1]

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.plot(liste_x,prediction,color = 'r')
model.summary()
plt.show()
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Comment modifier le réseau de neurones pour séparer les 2 classes ?
#
# * Maintenant les données d'entrée sont de dimension 2, en entrée on met x et y c'est à dire X1
# * Le réseau comporte une seule couche d'entrée comportant un seul neurone. La fonction d'activation est la fonction sigmoide.
# * En sortie (output) on met la classe de Y1 dimension 1.

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)

model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=1,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))

#Création du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy']) # on compile mais on sauve l'historique d'apprentissage du réseau
# on pourra comme ça tracer les graphiques d'évolution des pertes et de la précision.

# entrée X1 de dimension 2 (x, y)
entree = X1
# sortie de dimension  1 (classe bipolaire)
sortie = Y1

#Entraînement du réseau 100 passages
hist = model.fit(x=entree,y=sortie,epochs=100)

#Print weights
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire l'appartenance de points à un classe : 
#print(X1)
A= [[2,2]]
B= [[-4,2]]
print(model.predict(A))
print(model.predict(B))
#print(A[0][1]) # valeur x de A

print('prediction A :')
print(model.predict(A))
print('prédiction B :')
print(model.predict(B))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1923 - accuracy: 0.6800
# Epoch 2/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1820 - accuracy: 0.7100
# Epoch 3/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1732 - accuracy: 0.7100
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1662 - accuracy: 0.7300
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1592 - accuracy: 0.7600
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1536 - accuracy: 0.7600
# Epoch 7/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1478 - accuracy: 0.7600
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.7600
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.7700
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1331 - accuracy: 0.7700
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1284 - accuracy: 0.7700
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1242 - accuracy: 0.7700
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1196 - accuracy: 0.7800
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.7900
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.8100
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.8200
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.8400
# Epoch 18/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.8500
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.8500
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0937 - accuracy: 0.8600
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.8800
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0867 - accuracy: 0.9000
# Epoch 23/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0834 - accuracy: 0.9000
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.9000
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9100
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9100
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9100
# Epoch 28/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0705 - accuracy: 0.9200
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9200
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9300
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9400
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0618 - accuracy: 0.9400
# Epoch 33/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0598 - accuracy: 0.9400
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9400
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0565 - accuracy: 0.9400
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0548 - accuracy: 0.9400
# Epoch 37/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0532 - accuracy: 0.9400
# Epoch 38/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0515 - accuracy: 0.9400
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0501 - accuracy: 0.9400
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0484 - accuracy: 0.9500
# Epoch 41/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0468 - accuracy: 0.9600
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9600
# Epoch 43/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 0.9600
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9700
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9700
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 0.9700
# Epoch 47/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9700
# Epoch 48/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 0.9800
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9800
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 0.9800
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 0.9800
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9800
# Epoch 53/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9800
# Epoch 54/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9800
# Epoch 55/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9800
# Epoch 56/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9800
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9800
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9800
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9800
# Epoch 60/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 0.9800
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9800
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9800
# Epoch 63/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 0.9800
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9800
# Epoch 65/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0263 - accuracy: 0.9800
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 0.9800
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 0.9800
# Epoch 68/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0250 - accuracy: 0.9800
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9800
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9800
# Epoch 71/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 0.9800
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9800
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9900
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 0.9900
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9900
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 0.9900
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9900
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9900
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9900
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9900
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 0.9900
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9900
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9900
# Epoch 84/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0199 - accuracy: 0.9900
# Epoch 85/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9900
# Epoch 86/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9900
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9900
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9900
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9900
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9900
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9900
# Epoch 92/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9900
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9900
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9900
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9900
# Epoch 96/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9900
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9900
# Epoch 98/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0173 - accuracy: 0.9900
# Epoch 99/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9900
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.9900
#
# Weights:
#
# [array([[ 1.094779 ],
#        [-0.5888923]], dtype=float32), array([2.158655], dtype=float32)]
# 1/1 [==============================] - 0s 60ms/step
# [[0.9597061]]
# 1/1 [==============================] - 0s 50ms/step
# [[0.03235034]]
# prediction A :
# 1/1 [==============================] - 0s 35ms/step
# [[0.9597061]]
# prédiction B :
# 1/1 [==============================] - 0s 39ms/step
# [[0.03235034]]

# %% [markdown]
# # Tracé des graphes avec deux points de tests : A et B

# %%
print('prediction A :')
print(model.predict(A))
print('prédiction B :')
print(model.predict(B))

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)

ax =plt.subplot(111)
plt.title("2 classes", fontsize="small")

#print(A)
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.scatter(A[0][0], A[0][1], marker="o",c='red', s=40, edgecolor="red")
plt.scatter(B[0][0], B[0][1], marker="o",c='blue', s=40, edgecolor="blue")

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
Ylim = (-xe*1.0792954 - 2.191928)/(-0.56038827)

plt.plot(xe,Ylim,color = 'r')
#model.summary()
plt.show()
# Out:
# prediction A :
# 1/1 [==============================] - 0s 62ms/step
# [[0.9597061]]
# prédiction B :
# 1/1 [==============================] - 0s 38ms/step
# [[0.03235034]]

# %% [markdown]
# # Visualisons l'évolution des erreurs et de la précision du modèle sur les données d'entrainement

# %%
# Représentation d'un nuage de points

fig, ax1 = plt.subplots(figsize=(6, 4))
ax2 = ax1.twiny()

plt.title('modèle pertes et précision')
ax1.plot(hist.history['loss'], 'g-', label = 'loss')
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()

ax2.plot(hist.history['accuracy'], 'b-', label ='accuracy')
ax2.set_ylabel('accuracy')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Exemple avec 3 classes ...
#
# * Combien de neurones doit comporter la couche d'entrée pour obtenir un résultat convenable ?
# Essayer de modifier le nombre de neurones de la couche d'entrée....
# La couche de sortie doit comporter obligatoirement 3 neurones car on utilise la fonction d'activation softmax et il y a 3 classes

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
from keras.utils import to_categorical
import numpy as np 
#from sklearn.cluster import kmeans_plusplus
from sklearn.datasets import make_blobs

# Generate sample data
n_samples = 4000
n_components = 3

X, y_true = make_blobs(
    n_samples=n_samples, centers=n_components, cluster_std=0.60, random_state=0
)

print('y_true :')
print(y_true)
#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)

model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=128,input_shape=[2],activation= 'relu',kernel_initializer = my_init))
#La couche de sortie, units vaut 3 mais activation softmax
model.add(Dense(units=3, activation='softmax'))

#Optimisation du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='categorical_crossentropy',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  3 (3 classes)
sortie = to_categorical(y_true) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 0 0
# 1 >  1 0 0    vecteur (y_true) > matrice binaire (sortie)
# 2 >  0 1 0


#Entraînement du réseau ? passages
model.fit(x=entree,y=sortie,epochs=20,verbose =0)

#Print weights
#print("")
#print("Weights: \n")
#print(model.get_weights())

#Prediction
A= [[2,2.1]]
B= [[-2,3]]
C= [[0,3.2]]
Apred = model.predict(A)
Bpred = model.predict(B)
Cpred = model.predict(C)

#Affichage des prédictions
#print(model.predict(B))
#print(A[0][1])

print('prediction A :')
print(f"[{Apred[0][0]:.2f},{Apred[0][1]:.2f},{Apred[0][2]:.2f}]")

print('prédiction B :')
print(f"[{Bpred[0][0]:.2f},{Bpred[0][1]:.2f},{Bpred[0][2]:.2f}]")

print('prédiction C :')
print(f"[{Cpred[0][0]:.2f},{Cpred[0][1]:.2f},{Cpred[0][2]:.2f}]")

# Tracés des points avec les prédistions pour A, B et C
plt.figure(figsize=(8, 8))
plt.subplot(111)

#colors = ["#4EACC5", "#FF9C34", "#4E9A06"]
colors = ["red", "green", "blue"]

for k, col in enumerate(colors):# k index , col couleur
    cluster_data = (y_true == k)# cluster succession de valeurs vraies ou fausses
    plt.scatter(X[cluster_data, 0], X[cluster_data, 1], c=col, marker=".", s=10)# X[cluster_data, 0] prend les valeurs X[i,0] pour lesquelles cluster_data[i]=True
plt.scatter(A[0][0], A[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(B[0][0], B[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(C[0][0], C[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.text(2, 1.6, f"[{Apred[0][0]:.1f},{Apred[0][1]:.1f},{Apred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(-2, 2.6, f"[{Bpred[0][0]:.1f},{Bpred[0][1]:.1f},{Bpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(0, 3.5, f"[{Cpred[0][0]:.1f},{Cpred[0][1]:.1f},{Cpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')

plt.title("3 classes", fontsize="small")
plt.show()
# Out:
# y_true :
# [2 2 0 ... 0 2 1]
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 41ms/step
# prediction A :
# [0.00,1.00,0.00]
# prédiction B :
# [0.00,0.00,1.00]
# prédiction C :
# [0.20,0.00,0.80]

# %% [markdown]
# # Traçons les différents domaines ....

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, model, steps=200,alpha=0.2,seuil=0.45):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha),(0, 0, 1,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    
    for i in range(0,3): 
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.1f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    ax.scatter(X[:,0], X[:,1], c=y, lw=1,marker=".", s=10)
    
    return fig, ax

plot_decision_boundary2(entree, sortie, model, alpha=0.2)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.6)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.8)
# Out:
# 1250/1250 [==============================] - 1s 866us/step
# 1250/1250 [==============================] - 1s 876us/step
# 1250/1250 [==============================] - 1s 868us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)
