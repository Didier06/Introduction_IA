# %% [markdown]
# # Classification avec deux distributions circulaires

# %%
## space for importing required libraries
from sklearn.datasets import make_classification, make_circles #libraries to generate data
import matplotlib.pyplot as plt # importing library to plot
import numpy as np #numpy library for data manipulation and plotting

# %% [markdown]
# # génération et affichage des 2 classes

# %%
np.random.seed(4)
numPoints = 200
X, y = make_circles(n_samples=numPoints,
  factor=.4, noise=.1) #function to yield non circle data provided by sklearn
X = 10 * X

f, ax = plt.subplots(figsize=(8, 6)) #plotting data
ax.scatter(X[:,0],X[:,1], c=y, s=50,cmap="RdBu")
plt.show()

# %% [markdown]
# # Création du réseau de neurones.
# ### Trois couches 10 , 10 et 2 neurones
# activation sigmoid, sigmoid et softmax pour la couche de sortie.

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=10,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))
#Couches intermédiaires
model.add(Dense(units=10,activation= 'sigmoid'))
#La couche de sortie, units vaut 2 mais activation softmax
model.add(Dense(units=2, activation='softmax'))


#Optimiseur SGD ou adam ("adam "alternatif à "sgd")
#opt = SGD(learning_rate=0.01) #w = w - learning_rate * grad
opt = Adam(learning_rate=0.01)
model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  2 (2 classes)
sortie = to_categorical(y) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 1
# 1 >  1 0     vecteur (y_true) > matrice binaire (sortie)


#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100)
model.predict([[0, 5],[1,9]])
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 2ms/step - loss: 0.2523 - accuracy: 0.4950
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.5100
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.5100
# Epoch 4/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.4950
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2520 - accuracy: 0.5000
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.5000
# Epoch 7/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2481 - accuracy: 0.5450
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.5000
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5000
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.6000
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.5100
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2455 - accuracy: 0.5150
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2425 - accuracy: 0.6550
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2415 - accuracy: 0.5100
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.6600
# Epoch 16/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.6950
# Epoch 17/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2312 - accuracy: 0.6500
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2257 - accuracy: 0.7350
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.6950
# Epoch 20/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2119 - accuracy: 0.7500
# Epoch 21/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.7950
# Epoch 22/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1946 - accuracy: 0.7700
# Epoch 23/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1824 - accuracy: 0.7900
# Epoch 24/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1730 - accuracy: 0.8400
# Epoch 25/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1639 - accuracy: 0.8200
# Epoch 26/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1565 - accuracy: 0.8050
# Epoch 27/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1530 - accuracy: 0.7950
# Epoch 28/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1483 - accuracy: 0.8150
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1456 - accuracy: 0.8200
# Epoch 30/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.8000
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1396 - accuracy: 0.8050
# Epoch 32/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1385 - accuracy: 0.7900
# Epoch 33/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1368 - accuracy: 0.8050
# Epoch 34/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1347 - accuracy: 0.8150
# Epoch 35/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1317 - accuracy: 0.8150
# Epoch 36/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1270 - accuracy: 0.8250
# Epoch 37/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 0.8400
# Epoch 38/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.8650
# Epoch 39/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9300
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0717 - accuracy: 0.9650
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0567 - accuracy: 0.9850
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 0.9950
# Epoch 43/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 44/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9950
# Epoch 45/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 46/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9950
# Epoch 47/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9950
# Epoch 48/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9950
# Epoch 49/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0175 - accuracy: 0.9950
# Epoch 50/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 0.9950
# Epoch 51/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 52/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 55/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 56/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 58/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9950
# Epoch 59/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 60/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 62/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 0.9950
# Epoch 63/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 64/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 65/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 66/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9950
# Epoch 67/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.9950
# Epoch 68/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 69/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 70/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 71/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 72/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 73/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 0.9950
# Epoch 74/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 75/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 76/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 77/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 78/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 79/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 80/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 81/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 82/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 83/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 84/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 85/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 87/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 88/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 89/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 90/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 92/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 95/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 96/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 97/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 98/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 99/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0035 - accuracy: 1.0000
# 1/1 [==============================] - 0s 107ms/step
# array([[0.1335312 , 0.8664687 ],
#        [0.9730162 , 0.02698383]], dtype=float32)

# %% [markdown]
# ## Tracé des zones de prédiction

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, NbClasses, model, steps=250,alpha=0.2,seuil=0.51):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    steps = steps
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    #fig, ax = plt.subplots()
    
    for i in range(0,NbClasses): 
        #labels1= labels[:,i]
        #print(labels1)
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.2f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    #print(y)
    ax.scatter(X[:,0], X[:,1], c= y,lw=1,marker=".", s=50,cmap="RdBu")
    
    return fig, ax

plot_decision_boundary2(entree, sortie[:,0], 2, model, alpha=0.2, seuil=0.5)
plot_decision_boundary2(entree, y, 2, model, alpha=0.2,seuil = 0.6)
plot_decision_boundary2(entree, y, 2, model, alpha=0.2,seuil = 0.9)
# Out:
# 1954/1954 [==============================] - 2s 869us/step
# 1954/1954 [==============================] - 2s 890us/step
# 1954/1954 [==============================] - 2s 876us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)

# %% [markdown]
# # Autre réseau avec des entrées élevées au carré
# * La grandeur d'entrée est remplacée par X*X avec un seul neurone.
#
# Dans ce cas là la courbe de séparation des classes sera forcément une ellipse !

# %%
my_init = initializers.Zeros() 
#my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model2=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model2.add(Dense(units=1,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))
#La couche de sortie, units vaut 2 mais activation softmax
model2.add(Dense(units=2, activation='softmax'))


#Optimiseur SGD ou adam ("adam "alternatif à "sgd")
#opt = SGD(learning_rate=0.01) #w = w - learning_rate * grad
opt = Adam(learning_rate=0.01)
model2.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree2 = X*X
#print("X", X)
#print("entree2 ", entree2)
# sortie2 de dimension  2 (2 classes)
sortie2 = to_categorical(y) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 1
# 1 >  1 0     vecteur (y_true) > matrice binaire (sortie)


#Entraînement du réseau 100 passages
#history2 = model2.fit(x=entree2,y=sortie2[:,0],epochs=100)
history2 = model2.fit(x=entree2,y=sortie2,epochs=100)
Test = np.array([[1,0],[1,6]])

resultat = model2.predict(Test)
print(resultat)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2391 - accuracy: 0.7500
# Epoch 2/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2318 - accuracy: 0.9800
# Epoch 3/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2255 - accuracy: 1.0000
# Epoch 4/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9900
# Epoch 5/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2101 - accuracy: 0.9800
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2019 - accuracy: 1.0000
# Epoch 7/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1936 - accuracy: 0.9950
# Epoch 8/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 1.0000
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1762 - accuracy: 1.0000
# Epoch 10/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1682 - accuracy: 1.0000
# Epoch 11/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1596 - accuracy: 1.0000
# Epoch 12/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1499 - accuracy: 0.9950
# Epoch 13/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1416 - accuracy: 1.0000
# Epoch 14/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1318 - accuracy: 1.0000
# Epoch 15/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 1.0000
# Epoch 16/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1163 - accuracy: 0.9900
# Epoch 17/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1084 - accuracy: 1.0000
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 1.0000
# Epoch 19/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 1.0000
# Epoch 20/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0871 - accuracy: 1.0000
# Epoch 21/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0807 - accuracy: 1.0000
# Epoch 22/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0751 - accuracy: 0.9950
# Epoch 23/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0700 - accuracy: 0.9950
# Epoch 24/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0653 - accuracy: 1.0000
# Epoch 25/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0612 - accuracy: 0.9950
# Epoch 26/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 27/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0501 - accuracy: 1.0000
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 30/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0463 - accuracy: 0.9950
# Epoch 31/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0432 - accuracy: 0.9950
# Epoch 32/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 33/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 34/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 35/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 36/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 37/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 38/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 39/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0280 - accuracy: 0.9950
# Epoch 40/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 41/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 43/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 44/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 45/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 46/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 47/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 48/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0195 - accuracy: 0.9950
# Epoch 49/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 50/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 51/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 52/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 53/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 55/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 56/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 57/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 58/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 59/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 60/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 62/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 63/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 64/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 66/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 67/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 68/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 69/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 70/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 71/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 72/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 73/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 74/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 0.9950
# Epoch 75/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 76/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 77/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 78/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 79/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 80/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 81/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 82/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 83/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 84/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 86/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 87/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 88/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 89/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 90/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 91/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 92/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 93/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 96/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 97/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 98/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 99/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# 1/1 [==============================] - 0s 42ms/step
# [[0.02881732 0.9711827 ]
#  [0.03177026 0.9682298 ]]

# %%
import matplotlib as mpl
def plot_decision_boundary3(X, y, NbClasses, model, steps=250,alpha=0.2,seuil=0.51):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    steps = steps
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)
    #print(xx)
    #print("--")
    #print(xx.ravel())
    # Make predictions across region of interest
    X2 = xx.ravel()
    Y2 = yy.ravel()
    labels = model2.predict(np.c_[X2**2, Y2**2])# mise en forme : ravel() 
    print("labels ", labels)

    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    #fig, ax = plt.subplots()
    for i in range(0,NbClasses): 
        #labels1= labels[:,i]
        #print(labels1)
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.2f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    #print(y)
    ax.scatter(X[:,0], X[:,1], c= y,lw=1,marker=".", s=50,cmap="RdBu")
    
    return fig, ax

plot_decision_boundary3(X, y=sortie2[:,0], NbClasses=2, model=model, steps=250, alpha=0.2, seuil=0.5)
# Out:
# 1954/1954 [==============================] - 2s 833us/step
# labels  [[0.9425983  0.05740178]
#  [0.9425983  0.05740179]
#  [0.94259816 0.05740181]
#  ...
#  [0.9425983  0.05740175]
#  [0.9425983  0.05740174]
#  [0.9425983  0.05740172]]
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)
