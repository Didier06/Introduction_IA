# %% [markdown]
# # Prédiction de Toxicité avec Keras et RDKit
# Dans ce notebook, nous allons construire un réseau de neurones avec Keras (TensorFlow) pour classifier des molécules (Toxique vs Non-Toxique) en utilisant les empreintes digitales de Morgan (Morgan Fingerprints).

# %%
# Installation des dépendances (décommentez et exécutez si nécessaire)
# !pip install rdkit tensorflow scikit-learn numpy

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

# 1. DONNÉES D'EXEMPLE
# 1 = Toxique, 0 = Non toxique
data = [
    ("c1ccccc1", 1),       # Benzène
    ("CCO", 0),            # Éthanol
    ("C(=O)O", 0),         # Acide formique
    ("C1=CC=C(C=C1)O", 1), # Phénol
    ("C", 0),              # Méthane
    ("C1=CC=C(C=C1)Cl", 1) # Chlorobenzène
]

smiles_list = [item[0] for item in data]
labels = [item[1] for item in data]

# %%
# On importe le nouveau générateur moderne
from rdkit.Chem import rdFingerprintGenerator

# 2. CONVERSION EN VECTEURS (Morgan Fingerprints - Méthode Moderne)
def smiles_to_fingerprint(smiles, radius=2, n_bits=2048):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return np.zeros((n_bits,))
    
    # Création du générateur (nouvelle méthode recommandée)
    mfpgen = rdFingerprintGenerator.GetMorganGenerator(radius=radius, fpSize=n_bits)
    
    # Génération de l'empreinte
    fp = mfpgen.GetFingerprint(mol)
    
    return np.array(fp)

X = np.array([smiles_to_fingerprint(s) for s in smiles_list])
y = np.array(labels)

# 3. SÉPARATION ENTRAÎNEMENT / TEST
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

print(f"Taille des données d'entraînement : {X_train.shape}")
print(f"Taille des données de test : {X_test.shape}")
# Out:
# Taille des données d'entraînement : (4, 2048)
# Taille des données de test : (2, 2048)

# %%
# 4. CRÉATION DU MODÈLE KERAS
model = keras.Sequential([
    # Couche d'entrée qui correspond à la taille de notre fingerprint (2048)
    keras.Input(shape=(2048,)),
    
    # Première couche cachée avec 64 neurones et activation ReLU
    layers.Dense(64, activation='relu'),
    
    # Couche de régularisation (Dropout) pour éviter le surapprentissage
    layers.Dropout(0.2),
    
    # Deuxième couche cachée avec 32 neurones
    layers.Dense(32, activation='relu'),
    
    # Couche de sortie : 1 neurone avec activation Sigmoid pour une probabilité (0 à 1)
    layers.Dense(1, activation='sigmoid')
])

# Compilation du modèle
# On utilise binary_crossentropy car c'est un problème de classification binaire
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                131136
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 133249 (520.50 KB)
# Trainable params: 133249 (520.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 5. ENTRAÎNEMENT DU MODÈLE
print("Début de l'entraînement...")
history = model.fit(
    X_train, y_train,
    epochs=50,           # Nombre de passages sur l'ensemble des données
    batch_size=2,        # Mise à jour des poids toutes les 2 molécules
    verbose=1,
    validation_data=(X_test, y_test)
)
print("Entraînement terminé !")
# Out:
# Début de l'entraînement...
# Epoch 1/50
# 2/2 [==============================] - 1s 137ms/step - loss: 0.7094 - accuracy: 0.0000e+00 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 2/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6915 - accuracy: 0.5000 - val_loss: 0.6903 - val_accuracy: 0.5000
# Epoch 3/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6731 - accuracy: 0.7500 - val_loss: 0.6885 - val_accuracy: 0.5000
# Epoch 4/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6759 - accuracy: 1.0000 - val_loss: 0.6869 - val_accuracy: 0.5000
# Epoch 5/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6635 - accuracy: 1.0000 - val_loss: 0.6855 - val_accuracy: 0.5000
# Epoch 6/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6265 - accuracy: 1.0000 - val_loss: 0.6832 - val_accuracy: 0.5000
# Epoch 7/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6366 - accuracy: 1.0000 - val_loss: 0.6808 - val_accuracy: 0.5000
# Epoch 8/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5982 - accuracy: 1.0000 - val_loss: 0.6785 - val_accuracy: 0.5000
# Epoch 9/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6099 - accuracy: 1.0000 - val_loss: 0.6763 - val_accuracy: 0.5000
# Epoch 10/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5978 - accuracy: 1.0000 - val_loss: 0.6742 - val_accuracy: 0.5000
# Epoch 11/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5748 - accuracy: 1.0000 - val_loss: 0.6718 - val_accuracy: 0.5000
# Epoch 12/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5975 - accuracy: 1.0000 - val_loss: 0.6694 - val_accuracy: 0.5000
# Epoch 13/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5458 - accuracy: 1.0000 - val_loss: 0.6670 - val_accuracy: 0.5000
# Epoch 14/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5394 - accuracy: 1.0000 - val_loss: 0.6639 - val_accuracy: 0.5000
# Epoch 15/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5364 - accuracy: 1.0000 - val_loss: 0.6605 - val_accuracy: 0.5000
# Epoch 16/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4944 - accuracy: 1.0000 - val_loss: 0.6572 - val_accuracy: 0.5000
# Epoch 17/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5262 - accuracy: 1.0000 - val_loss: 0.6545 - val_accuracy: 0.5000
# Epoch 18/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4984 - accuracy: 1.0000 - val_loss: 0.6515 - val_accuracy: 0.5000
# Epoch 19/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4697 - accuracy: 1.0000 - val_loss: 0.6484 - val_accuracy: 0.5000
# Epoch 20/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4524 - accuracy: 1.0000 - val_loss: 0.6453 - val_accuracy: 0.5000
# Epoch 21/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4531 - accuracy: 1.0000 - val_loss: 0.6419 - val_accuracy: 0.5000
# Epoch 22/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4310 - accuracy: 1.0000 - val_loss: 0.6379 - val_accuracy: 0.5000
# Epoch 23/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4520 - accuracy: 1.0000 - val_loss: 0.6339 - val_accuracy: 0.5000
# Epoch 24/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4355 - accuracy: 1.0000 - val_loss: 0.6295 - val_accuracy: 0.5000
# Epoch 25/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3835 - accuracy: 1.0000 - val_loss: 0.6254 - val_accuracy: 0.5000
# Epoch 26/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3912 - accuracy: 1.0000 - val_loss: 0.6208 - val_accuracy: 0.5000
# Epoch 27/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3674 - accuracy: 1.0000 - val_loss: 0.6159 - val_accuracy: 0.5000
# Epoch 28/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3991 - accuracy: 1.0000 - val_loss: 0.6109 - val_accuracy: 0.5000
# Epoch 29/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3941 - accuracy: 1.0000 - val_loss: 0.6058 - val_accuracy: 0.5000
# Epoch 30/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3728 - accuracy: 1.0000 - val_loss: 0.6005 - val_accuracy: 0.5000
# Epoch 31/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3752 - accuracy: 1.0000 - val_loss: 0.5951 - val_accuracy: 0.5000
# Epoch 32/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2832 - accuracy: 1.0000 - val_loss: 0.5899 - val_accuracy: 0.5000
# Epoch 33/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2972 - accuracy: 1.0000 - val_loss: 0.5843 - val_accuracy: 0.5000
# Epoch 34/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2762 - accuracy: 1.0000 - val_loss: 0.5785 - val_accuracy: 0.5000
# Epoch 35/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2547 - accuracy: 1.0000 - val_loss: 0.5725 - val_accuracy: 0.5000
# Epoch 36/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2569 - accuracy: 1.0000 - val_loss: 0.5663 - val_accuracy: 0.5000
# Epoch 37/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2486 - accuracy: 1.0000 - val_loss: 0.5598 - val_accuracy: 0.5000
# Epoch 38/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2439 - accuracy: 1.0000 - val_loss: 0.5527 - val_accuracy: 0.5000
# Epoch 39/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2320 - accuracy: 1.0000 - val_loss: 0.5461 - val_accuracy: 0.5000
# Epoch 40/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2356 - accuracy: 1.0000 - val_loss: 0.5394 - val_accuracy: 0.5000
# Epoch 41/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2316 - accuracy: 1.0000 - val_loss: 0.5325 - val_accuracy: 0.5000
# Epoch 42/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1905 - accuracy: 1.0000 - val_loss: 0.5255 - val_accuracy: 0.5000
# Epoch 43/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1961 - accuracy: 1.0000 - val_loss: 0.5179 - val_accuracy: 0.5000
# Epoch 44/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1789 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.5000
# Epoch 45/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1891 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.5000
# Epoch 46/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1741 - accuracy: 1.0000 - val_loss: 0.4949 - val_accuracy: 0.5000
# Epoch 47/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1782 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.5000
# Epoch 48/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1587 - accuracy: 1.0000 - val_loss: 0.4790 - val_accuracy: 0.5000
# Epoch 49/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1444 - accuracy: 1.0000 - val_loss: 0.4711 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1260 - accuracy: 1.0000 - val_loss: 0.4636 - val_accuracy: 1.0000
# Entraînement terminé !

# %%
# 6. ÉVALUATION ET PRÉDICTION SUR UNE NOUVELLE MOLÉCULE
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Précision sur le jeu de test : {accuracy * 100:.2f}%\n")

nouvelle_molecule_smiles = "c1ccccc1C" # Toluène
nouvelle_empreinte = smiles_to_fingerprint(nouvelle_molecule_smiles)
nouvelle_empreinte = nouvelle_empreinte.reshape(1, -1) # Keras attend (batch_size, n_features)

# Prédire la probabilité (entre 0 et 1)
probabilite = model.predict(nouvelle_empreinte, verbose=0)[0][0]

print(f"--- Analyse du Toluène ({nouvelle_molecule_smiles}) ---")
if probabilite >= 0.5:
    print(f"Prédiction : TOXIQUE (Confiance : {probabilite*100:.2f}%)")
else:
    print(f"Prédiction : NON TOXIQUE (Confiance : {(1-probabilite)*100:.2f}%)")
# Out:
# Précision sur le jeu de test : 100.00%
#
# --- Analyse du Toluène (c1ccccc1C) ---
# Prédiction : TOXIQUE (Confiance : 90.48%)
