# %% [markdown]
# # Prédiction de Toxicité avec Keras et RDKit
# Dans ce notebook, nous allons construire un réseau de neurones avec Keras (TensorFlow) pour classifier des molécules (Toxique vs Non-Toxique) en utilisant les empreintes digitales de Morgan (Morgan Fingerprints).

# %%
# Installation des dépendances (décommentez et exécutez si nécessaire)
# !pip install rdkit tensorflow scikit-learn numpy

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

# 1. DONNÉES D'EXEMPLE
# 1 = Toxique, 0 = Non toxique
data = [
    ("c1ccccc1", 1),       # Benzène
    ("CCO", 0),            # Éthanol
    ("C(=O)O", 0),         # Acide formique
    ("C1=CC=C(C=C1)O", 1), # Phénol
    ("C", 0),              # Méthane
    ("C1=CC=C(C=C1)Cl", 1) # Chlorobenzène
]

smiles_list = [item[0] for item in data]
labels = [item[1] for item in data]

# %%
# On importe le nouveau générateur moderne
from rdkit.Chem import rdFingerprintGenerator

# 2. CONVERSION EN VECTEURS (Morgan Fingerprints - Méthode Moderne)
def smiles_to_fingerprint(smiles, radius=2, n_bits=2048):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return np.zeros((n_bits,))
    
    # Création du générateur (nouvelle méthode recommandée)
    mfpgen = rdFingerprintGenerator.GetMorganGenerator(radius=radius, fpSize=n_bits)
    
    # Génération de l'empreinte
    fp = mfpgen.GetFingerprint(mol)
    
    return np.array(fp)

X = np.array([smiles_to_fingerprint(s) for s in smiles_list])
y = np.array(labels)

# 3. SÉPARATION ENTRAÎNEMENT / TEST
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

print(f"Taille des données d'entraînement : {X_train.shape}")
print(f"Taille des données de test : {X_test.shape}")
# Out:
# Taille des données d'entraînement : (4, 2048)
# Taille des données de test : (2, 2048)

# %%
# 4. CRÉATION DU MODÈLE KERAS
model = keras.Sequential([
    # Couche d'entrée qui correspond à la taille de notre fingerprint (2048)
    keras.Input(shape=(2048,)),
    
    # Première couche cachée avec 64 neurones et activation ReLU
    layers.Dense(64, activation='relu'),
    
    # Couche de régularisation (Dropout) pour éviter le surapprentissage
    layers.Dropout(0.2),
    
    # Deuxième couche cachée avec 32 neurones
    layers.Dense(32, activation='relu'),
    
    # Couche de sortie : 1 neurone avec activation Sigmoid pour une probabilité (0 à 1)
    layers.Dense(1, activation='sigmoid')
])

# Compilation du modèle
# On utilise binary_crossentropy car c'est un problème de classification binaire
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                131136
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 133249 (520.50 KB)
# Trainable params: 133249 (520.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 5. ENTRAÎNEMENT DU MODÈLE
print("Début de l'entraînement...")
history = model.fit(
    X_train, y_train,
    epochs=50,           # Nombre de passages sur l'ensemble des données
    batch_size=2,        # Mise à jour des poids toutes les 2 molécules
    verbose=1,
    validation_data=(X_test, y_test)
)
print("Entraînement terminé !")
# Out:
# Début de l'entraînement...
# Epoch 1/50
# 2/2 [==============================] - 1s 171ms/step - loss: 0.6936 - accuracy: 0.5000 - val_loss: 0.6724 - val_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6640 - accuracy: 1.0000 - val_loss: 0.6690 - val_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6559 - accuracy: 1.0000 - val_loss: 0.6658 - val_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6465 - accuracy: 1.0000 - val_loss: 0.6629 - val_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6254 - accuracy: 1.0000 - val_loss: 0.6596 - val_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6258 - accuracy: 1.0000 - val_loss: 0.6561 - val_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6117 - accuracy: 1.0000 - val_loss: 0.6523 - val_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5911 - accuracy: 1.0000 - val_loss: 0.6482 - val_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6083 - accuracy: 1.0000 - val_loss: 0.6437 - val_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5692 - accuracy: 1.0000 - val_loss: 0.6389 - val_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5753 - accuracy: 1.0000 - val_loss: 0.6335 - val_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5541 - accuracy: 1.0000 - val_loss: 0.6282 - val_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5312 - accuracy: 1.0000 - val_loss: 0.6228 - val_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5255 - accuracy: 1.0000 - val_loss: 0.6169 - val_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5228 - accuracy: 1.0000 - val_loss: 0.6105 - val_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5159 - accuracy: 1.0000 - val_loss: 0.6035 - val_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4918 - accuracy: 1.0000 - val_loss: 0.5964 - val_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4707 - accuracy: 1.0000 - val_loss: 0.5887 - val_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4640 - accuracy: 1.0000 - val_loss: 0.5808 - val_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4716 - accuracy: 1.0000 - val_loss: 0.5728 - val_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4299 - accuracy: 1.0000 - val_loss: 0.5646 - val_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4068 - accuracy: 1.0000 - val_loss: 0.5566 - val_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3958 - accuracy: 1.0000 - val_loss: 0.5484 - val_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4071 - accuracy: 1.0000 - val_loss: 0.5400 - val_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3603 - accuracy: 1.0000 - val_loss: 0.5316 - val_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3293 - accuracy: 1.0000 - val_loss: 0.5231 - val_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3373 - accuracy: 1.0000 - val_loss: 0.5144 - val_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3488 - accuracy: 1.0000 - val_loss: 0.5053 - val_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3091 - accuracy: 1.0000 - val_loss: 0.4962 - val_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3369 - accuracy: 1.0000 - val_loss: 0.4872 - val_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2793 - accuracy: 1.0000 - val_loss: 0.4784 - val_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2581 - accuracy: 1.0000 - val_loss: 0.4697 - val_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3180 - accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2594 - accuracy: 1.0000 - val_loss: 0.4524 - val_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2228 - accuracy: 1.0000 - val_loss: 0.4436 - val_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2208 - accuracy: 1.0000 - val_loss: 0.4349 - val_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2194 - accuracy: 1.0000 - val_loss: 0.4262 - val_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2130 - accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1883 - accuracy: 1.0000 - val_loss: 0.4089 - val_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1974 - accuracy: 1.0000 - val_loss: 0.4006 - val_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1954 - accuracy: 1.0000 - val_loss: 0.3921 - val_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1901 - accuracy: 1.0000 - val_loss: 0.3832 - val_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1608 - accuracy: 1.0000 - val_loss: 0.3745 - val_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1578 - accuracy: 1.0000 - val_loss: 0.3658 - val_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1439 - accuracy: 1.0000 - val_loss: 0.3574 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1304 - accuracy: 1.0000 - val_loss: 0.3490 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1197 - accuracy: 1.0000 - val_loss: 0.3412 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1188 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1260 - accuracy: 1.0000 - val_loss: 0.3256 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1108 - accuracy: 1.0000 - val_loss: 0.3178 - val_accuracy: 1.0000
# Entraînement terminé !

# %%
# 6. ÉVALUATION ET PRÉDICTION SUR UNE NOUVELLE MOLÉCULE
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Précision sur le jeu de test : {accuracy * 100:.2f}%\n")

nouvelle_molecule_smiles = "c1ccccc1C" # Toluène
nouvelle_empreinte = smiles_to_fingerprint(nouvelle_molecule_smiles)
nouvelle_empreinte = nouvelle_empreinte.reshape(1, -1) # Keras attend (batch_size, n_features)

# Prédire la probabilité (entre 0 et 1)
probabilite = model.predict(nouvelle_empreinte, verbose=0)[0][0]

print(f"--- Analyse du Toluène ({nouvelle_molecule_smiles}) ---")
if probabilite >= 0.5:
    print(f"Prédiction : TOXIQUE (Confiance : {probabilite*100:.2f}%)")
else:
    print(f"Prédiction : NON TOXIQUE (Confiance : {(1-probabilite)*100:.2f}%)")
# Out:
# Précision sur le jeu de test : 100.00%
#
# --- Analyse du Toluène (c1ccccc1C) ---
# Prédiction : TOXIQUE (Confiance : 89.95%)
