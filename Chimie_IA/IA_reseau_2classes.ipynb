# %% [markdown]
# # Génération de 2 classes de points
# * NbbPoints - nombre total de points à générer.
# * Chaque point a 3 caractéristiques : x, y, et type de classe  (0 pour la première classe et 1 pour la deuxième).

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("2 classes de points", fontsize="small")
centers = [(-4, 2), (0, 0)] # centre des classes
# création des 2 classes  
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10) 
# X1 contient les coordonnées x,y de chaque popint et Y1 est la classe des points 0 : 1ère classe  et 1 2ème classe
#print(X1)
#print(Y1)

# Xe et Xs sont dans un premier temps les entrées et sorties du réseau 
Xe = X1[:,0] # entrée x
Xs = X1[:,1] # entrée y
#print(Xe)
#print()

# tracé des points sur le graphe avec  leur étiquette correspondante en couleur
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.show()

# %% [markdown]
# # Création du réseau séquentiel avec des fonctions d'activation identité (linéaire)

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape doit être égale à 1 + couche 3 neurones units = 3
model.add(Dense(units=1,input_shape=[1],activation= 'linear',kernel_initializer = my_init))
# créer ici votre réseau de neurones avec une couche et un neurone avec une entrée Xe et la sortie Xs
#model.add(Dense(units=1, activation='linear'))
#Création de l'optimiseur ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['mse'])
entree = Xe
sortie = Xs

#Entraînement du réseau 1000 passages (1000 époques)
model.fit(x=entree,y=sortie,epochs=100, batch_size=32)

#Affichage des poids
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
prediction = model.predict(xe)

# on obtient une régression linéaire ! on n'a pas séparé les classes de 2 points !
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 3ms/step - loss: 18.8108 - mse: 18.8108
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 17.6882 - mse: 17.6882
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 16.5989 - mse: 16.5989
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 15.5294 - mse: 15.5294
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 14.5351 - mse: 14.5351
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 13.4946 - mse: 13.4946
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 12.5678 - mse: 12.5678
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 11.6895 - mse: 11.6895
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 10.8291 - mse: 10.8291
# Epoch 10/100
# 4/4 [==============================] - 0s 3ms/step - loss: 10.1077 - mse: 10.1077
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4148 - mse: 9.4148
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 8.7671 - mse: 8.7671
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 8.1765 - mse: 8.1765
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 7.6085 - mse: 7.6085
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 7.0598 - mse: 7.0598
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 6.5485 - mse: 6.5485
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 6.0418 - mse: 6.0418
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 5.6311 - mse: 5.6311
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/step - loss: 5.2324 - mse: 5.2324
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.8738 - mse: 4.8738
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.5615 - mse: 4.5615
# Epoch 22/100
# 4/4 [==============================] - 0s 1ms/step - loss: 4.2714 - mse: 4.2714
# Epoch 23/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9780 - mse: 3.9780
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.7237 - mse: 3.7237
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.4671 - mse: 3.4671
# Epoch 26/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.2513 - mse: 3.2513
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0610 - mse: 3.0610
# Epoch 28/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.8812 - mse: 2.8812
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7220 - mse: 2.7220
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5937 - mse: 2.5937
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4758 - mse: 2.4758
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3720 - mse: 2.3720
# Epoch 33/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2850 - mse: 2.2850
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2162 - mse: 2.2162
# Epoch 35/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1509 - mse: 2.1509
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0882 - mse: 2.0882
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0299 - mse: 2.0299
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9768 - mse: 1.9768
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9291 - mse: 1.9291
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8870 - mse: 1.8870
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8485 - mse: 1.8485
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8161 - mse: 1.8161
# Epoch 43/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7863 - mse: 1.7863
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7589 - mse: 1.7589
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7323 - mse: 1.7323
# Epoch 46/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.7048 - mse: 1.7048
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6823 - mse: 1.6823
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6583 - mse: 1.6583
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6361 - mse: 1.6361
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6156 - mse: 1.6156
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5958 - mse: 1.5958
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5770 - mse: 1.5770
# Epoch 53/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5613 - mse: 1.5613
# Epoch 54/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5493 - mse: 1.5493
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5356 - mse: 1.5356
# Epoch 56/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5252 - mse: 1.5252
# Epoch 57/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5151 - mse: 1.5151
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5057 - mse: 1.5057
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4963 - mse: 1.4963
# Epoch 60/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4866 - mse: 1.4866
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4777 - mse: 1.4777
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4696 - mse: 1.4696
# Epoch 63/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4597 - mse: 1.4597
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4520 - mse: 1.4520
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4450 - mse: 1.4450
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4393 - mse: 1.4393
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4330 - mse: 1.4330
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4287 - mse: 1.4287
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4236 - mse: 1.4236
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4186 - mse: 1.4186
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4131 - mse: 1.4131
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4082 - mse: 1.4082
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4031 - mse: 1.4031
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3974 - mse: 1.3974
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3928 - mse: 1.3928
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3884 - mse: 1.3884
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3838 - mse: 1.3838
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3801 - mse: 1.3801
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3760 - mse: 1.3760
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3720 - mse: 1.3720
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3677 - mse: 1.3677
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3638 - mse: 1.3638
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3603 - mse: 1.3603
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3580 - mse: 1.3580
# Epoch 85/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3557 - mse: 1.3557
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3533 - mse: 1.3533
# Epoch 87/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3504 - mse: 1.3504
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3472 - mse: 1.3472
# Epoch 89/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3447 - mse: 1.3447
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3395 - mse: 1.3395
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3359 - mse: 1.3359
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3330 - mse: 1.3330
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3309 - mse: 1.3309
# Epoch 94/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3279 - mse: 1.3279
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3258 - mse: 1.3258
# Epoch 96/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3243 - mse: 1.3243
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3218 - mse: 1.3218
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3192 - mse: 1.3192
# Epoch 99/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3172 - mse: 1.3172
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3157 - mse: 1.3157
#
# Weights:
#
# [array([[-0.32049814]], dtype=float32), array([0.5055916], dtype=float32)]
# 2/2 [==============================] - 0s 3ms/step

# %% [markdown]
# # Retraçons les points et le droite obtenue :

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("Two classes", fontsize="small")
centers = [(-4, 2), (0, 0)]
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10,center_box=(-10.0, 10.0))

Xe = X1[:,0]
Xs = X1[:,1]

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.plot(liste_x,prediction,color = 'r')
model.summary()
plt.show()
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Comment modifier le réseau de neurones pour séparer les 2 classes ?
#
# * Maintenant les données d'entrée sont de dimension 2, en entrée on met x et y c'est à dire X1
# * Le réseau comporte une seule couche d'entrée comportant un seul neurone. La fonction d'activation est la fonction sigmoide.
# * En sortie (output) on met la classe de Y1 dimension 1.

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=1,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))

#Création du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy']) # on compile mais on sauve l'historique d'apprentissage du réseau
# on pourra comme ça tracer les graphiques d'évolution des pertes et de la précision.

# entrée X1 de dimension 2 (x, y)
entree = X1
# sortie de dimension  1 (classe bipolaire)
sortie = Y1

#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100)

#Print weights
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire l'appartenance de points à un classe : 
#print(X1)
A= [[2,2]]
A_array = np.array(A)
B= [[-4,2]]
B_array = np.array(B)

#print(A[0][1]) # valeur x de A

print('prediction A :')
print(model.predict(A_array))
print('prédiction B :')
print(model.predict(B_array))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1916 - accuracy: 0.6800
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1830 - accuracy: 0.7100
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.7100
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1691 - accuracy: 0.7300
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1630 - accuracy: 0.7500
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1572 - accuracy: 0.7600
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.7600
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.7600
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.7600
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1357 - accuracy: 0.7700
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1314 - accuracy: 0.7700
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1269 - accuracy: 0.7700
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.7800
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1191 - accuracy: 0.7800
# Epoch 15/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1151 - accuracy: 0.7900
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1118 - accuracy: 0.8200
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.8400
# Epoch 18/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.8400
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1006 - accuracy: 0.8500
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.8500
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.8700
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.8800
# Epoch 23/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0877 - accuracy: 0.8800
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9000
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9000
# Epoch 26/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0791 - accuracy: 0.9100
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0764 - accuracy: 0.9100
# Epoch 28/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0738 - accuracy: 0.9100
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9100
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9200
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0670 - accuracy: 0.9300
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 0.9300
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0629 - accuracy: 0.9400
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9400
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9400
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0576 - accuracy: 0.9400
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 0.9400
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 0.9400
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9400
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0518 - accuracy: 0.9400
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9400
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9500
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0479 - accuracy: 0.9500
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9500
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 0.9600
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9600
# Epoch 47/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9600
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9700
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0412 - accuracy: 0.9700
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9700
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 0.9700
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9700
# Epoch 53/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9700
# Epoch 54/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 0.9800
# Epoch 55/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9800
# Epoch 56/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 0.9800
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9800
# Epoch 58/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0332 - accuracy: 0.9800
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 0.9800
# Epoch 60/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0318 - accuracy: 0.9800
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9800
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9800
# Epoch 63/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 0.9800
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.9800
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9800
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 0.9800
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9800
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9800
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9800
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9800
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9800
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9800
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9800
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9800
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9800
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9800
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9800
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9800
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9800
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9800
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 0.9800
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9800
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9800
# Epoch 84/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 0.9800
# Epoch 85/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9800
# Epoch 86/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9800
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9900
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9900
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9900
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9900
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9900
# Epoch 92/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9900
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9900
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 0.9900
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9900
# Epoch 96/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9900
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.9900
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9900
# Epoch 99/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9900
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9900
#
# Weights:
#
# [array([[ 1.0965903],
#        [-0.525198 ]], dtype=float32), array([2.168834], dtype=float32)]
# prediction A :
# 1/1 [==============================] - 0s 40ms/step
# [[0.9648253]]
# prédiction B :
# 1/1 [==============================] - 0s 25ms/step
# [[0.03668816]]

# %% [markdown]
# # Tracé des graphes avec deux points de tests : A et B

# %%
print('prediction A :')
print(model.predict(A))
print('prédiction B :')
print(model.predict(B))

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)

ax =plt.subplot(111)
plt.title("2 classes", fontsize="small")

#print(A)
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.scatter(A[0][0], A[0][1], marker="o",c='red', s=40, edgecolor="red")
plt.scatter(B[0][0], B[0][1], marker="o",c='blue', s=40, edgecolor="blue")

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
Ylim = (-xe*1.0792954 - 2.191928)/(-0.56038827)

plt.plot(xe,Ylim,color = 'r')
#model.summary()
plt.show()
# Out:
# prediction A :
# 1/1 [==============================] - 0s 48ms/step
# [[0.9648253]]
# prédiction B :
# 1/1 [==============================] - 0s 53ms/step
# [[0.03668816]]

# %% [markdown]
# # Visualisons l'évolution des erreurs et de la précision du modèle sur les données d'entrainement

# %%
# list all data in history

# Représentation d'un nuage de points

fig, ax1 = plt.subplots(figsize=(6, 4))
ax2 = ax1.twiny()

plt.title('modèle pertes et précision')
ax1.plot(history.history['loss'], 'g-', label = 'loss')
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()

ax2.plot(history.history['accuracy'], 'b-', label ='accuracy')
ax2.set_ylabel('accuracy')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Exemple avec 3 classes ...
#
# * Combien de neurones doit comporter la couche d'entrée pour obtenir un résultat convenable ?
# Essayer de modifier le nombre de neurones de la couche d'entrée....
# La couche de sortie doit comporter obligatoirement 3 neurones car on utilise la fonction d'activation softmax et il y a 3 classes

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
from keras.utils import to_categorical
import numpy as np 
#from sklearn.cluster import kmeans_plusplus
from sklearn.datasets import make_blobs

# Generate sample data
n_samples = 4000
n_components = 3

X, y_true = make_blobs(
    n_samples=n_samples, centers=n_components, cluster_std=0.60, random_state=0
)

print('y_true :')
print(y_true)
#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)

model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=128,input_shape=[2],activation= 'relu',kernel_initializer = my_init))
#La couche de sortie, units vaut 3 mais activation softmax
model.add(Dense(units=3, activation='softmax'))

#Optimisation du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='categorical_crossentropy',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  3 (3 classes)
sortie = to_categorical(y_true) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 0 0
# 1 >  1 0 0    vecteur (y_true) > matrice binaire (sortie)
# 2 >  0 1 0


#Entraînement du réseau ? passages
model.fit(x=entree,y=sortie,epochs=20,verbose =0)

#Print weights
#print("")
#print("Weights: \n")
#print(model.get_weights())

#Prediction
A= [[2,2.1]]
B= [[-2,3]]
C= [[0,3.2]]
Apred = model.predict(A)
Bpred = model.predict(B)
Cpred = model.predict(C)

#Affichage des prédictions
#print(model.predict(B))
#print(A[0][1])

print('prediction A :')
print(f"[{Apred[0][0]:.2f},{Apred[0][1]:.2f},{Apred[0][2]:.2f}]")

print('prédiction B :')
print(f"[{Bpred[0][0]:.2f},{Bpred[0][1]:.2f},{Bpred[0][2]:.2f}]")

print('prédiction C :')
print(f"[{Cpred[0][0]:.2f},{Cpred[0][1]:.2f},{Cpred[0][2]:.2f}]")

# Tracés des points avec les prédistions pour A, B et C
plt.figure(figsize=(8, 8))
plt.subplot(111)

#colors = ["#4EACC5", "#FF9C34", "#4E9A06"]
colors = ["red", "green", "blue"]

for k, col in enumerate(colors):# k index , col couleur
    cluster_data = (y_true == k)# cluster succession de valeurs vraies ou fausses
    plt.scatter(X[cluster_data, 0], X[cluster_data, 1], c=col, marker=".", s=10)# X[cluster_data, 0] prend les valeurs X[i,0] pour lesquelles cluster_data[i]=True
plt.scatter(A[0][0], A[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(B[0][0], B[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(C[0][0], C[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.text(2, 1.6, f"[{Apred[0][0]:.1f},{Apred[0][1]:.1f},{Apred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(-2, 2.6, f"[{Bpred[0][0]:.1f},{Bpred[0][1]:.1f},{Bpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(0, 3.5, f"[{Cpred[0][0]:.1f},{Cpred[0][1]:.1f},{Cpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')

plt.title("3 classes", fontsize="small")
plt.show()
# Out:
# y_true :
# [2 2 0 ... 0 2 1]
# 1/1 [==============================] - 0s 76ms/step
# WARNING:tensorflow:5 out of the last 3760 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002A1E654F420> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 40ms/step
# prediction A :
# [0.00,1.00,0.00]
# prédiction B :
# [0.00,0.00,1.00]
# prédiction C :
# [0.24,0.00,0.76]

# %% [markdown]
# # Traçons les différents domaines ....

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, model, steps=200,alpha=0.2,seuil=0.45):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha),(0, 0, 1,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        bounds = [0, 0.5, 1]
        norm = mpl.colors.BoundaryNorm(bounds, cmap.N) 
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    
    for i in range(0,3): 
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.1f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    ax.scatter(X[:,0], X[:,1], c=y, lw=1,marker=".", s=10)
    
    return fig, ax

plot_decision_boundary2(entree, sortie, model, alpha=0.2)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.6)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.8)
# Out:
# 1250/1250 [==============================] - 1s 884us/step
# 1250/1250 [==============================] - 1s 868us/step
# 1250/1250 [==============================] - 1s 865us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)
