# %% [markdown]
# # Génération de 2 classes de points
# * NbbPoints - nombre total de points à générer.
# * Chaque point a 3 caractéristiques : x, y, et type de classe  (0 pour la première classe et 1 pour la deuxième).

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("2 classes de points", fontsize="small")
centers = [(-4, 2), (0, 0)] # centre des classes
# création des 2 classes  
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10) 
# X1 contient les coordonnées x,y de chaque popint et Y1 est la classe des points 0 : 1ère classe  et 1 2ème classe
#print(X1)
#print(Y1)

# Xe et Xs sont dans un premier temps les entrées et sorties du réseau 
Xe = X1[:,0] # entrée x
Xs = X1[:,1] # entrée y
#print(Xe)
#print()

# tracé des points sur le graphe avec  leur étiquette correspondante en couleur
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.show()

# %% [markdown]
# # Création du réseau séquentiel avec des fonctions d'activation identité (linéaire)

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)

model=Sequential()
#pour La couche d'entrée, input_shape doit être égale à 1 + couche 3 neurones units = 3
model.add(Dense(units=1,input_shape=[1],activation= 'linear',kernel_initializer = my_init))
# créer ici votre réseau de neurones avec une couche et un neurone avec une entrée Xe et la sortie Xs
#model.add(Dense(units=1, activation='linear'))
#Création de l'optimiseur ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['mse'])
entree = Xe
sortie = Xs

#Entraînement du réseau 1000 passages (1000 époques)
model.fit(x=entree,y=sortie,epochs=100, batch_size=32)

#Affichage des poids
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
prediction = model.predict(xe)

# on obtient une régression linéaire ! on n'a pas séparé les classes de 2 points !
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 18.8207 - mse: 18.8207
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 17.6551 - mse: 17.6551
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 16.5671 - mse: 16.5671
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 15.5024 - mse: 15.5024
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 14.4415 - mse: 14.4415
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 13.4902 - mse: 13.4902
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 12.5468 - mse: 12.5468
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 11.6493 - mse: 11.6493
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 10.7984 - mse: 10.7984
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 10.0357 - mse: 10.0357
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.3244 - mse: 9.3244
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 8.7413 - mse: 8.7413
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 8.1108 - mse: 8.1108
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 7.5539 - mse: 7.5539
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 7.0167 - mse: 7.0167
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 6.4722 - mse: 6.4722
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 6.0001 - mse: 6.0001
# Epoch 18/100
# 4/4 [==============================] - 0s 2ms/step - loss: 5.6133 - mse: 5.6133
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/step - loss: 5.1876 - mse: 5.1876
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.8171 - mse: 4.8171
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.4988 - mse: 4.4988
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.2234 - mse: 4.2234
# Epoch 23/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9850 - mse: 3.9850
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.7475 - mse: 3.7475
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.5368 - mse: 3.5368
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.3340 - mse: 3.3340
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.1620 - mse: 3.1620
# Epoch 28/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.9901 - mse: 2.9901
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.8327 - mse: 2.8327
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7002 - mse: 2.7002
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5872 - mse: 2.5872
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4762 - mse: 2.4762
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3830 - mse: 2.3830
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2863 - mse: 2.2863
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2012 - mse: 2.2012
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1283 - mse: 2.1283
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0629 - mse: 2.0629
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9986 - mse: 1.9986
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9511 - mse: 1.9511
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8976 - mse: 1.8976
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8559 - mse: 1.8559
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8219 - mse: 1.8219
# Epoch 43/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7820 - mse: 1.7820
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7527 - mse: 1.7527
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7186 - mse: 1.7186
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6945 - mse: 1.6945
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6730 - mse: 1.6730
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6545 - mse: 1.6545
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6329 - mse: 1.6329
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6175 - mse: 1.6175
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6010 - mse: 1.6010
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5871 - mse: 1.5871
# Epoch 53/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5729 - mse: 1.5729
# Epoch 54/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5604 - mse: 1.5604
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5464 - mse: 1.5464
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5338 - mse: 1.5338
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5216 - mse: 1.5216
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5098 - mse: 1.5098
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4997 - mse: 1.4997
# Epoch 60/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4905 - mse: 1.4905
# Epoch 61/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4801 - mse: 1.4801
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4715 - mse: 1.4715
# Epoch 63/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4650 - mse: 1.4650
# Epoch 64/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4574 - mse: 1.4574
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4502 - mse: 1.4502
# Epoch 66/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4445 - mse: 1.4445
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4385 - mse: 1.4385
# Epoch 68/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4323 - mse: 1.4323
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4273 - mse: 1.4273
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4225 - mse: 1.4225
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4181 - mse: 1.4181
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4130 - mse: 1.4130
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4086 - mse: 1.4086
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4017 - mse: 1.4017
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3960 - mse: 1.3960
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3912 - mse: 1.3912
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3870 - mse: 1.3870
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3825 - mse: 1.3825
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3788 - mse: 1.3788
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3755 - mse: 1.3755
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3710 - mse: 1.3710
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3679 - mse: 1.3679
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3630 - mse: 1.3630
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3593 - mse: 1.3593
# Epoch 85/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3557 - mse: 1.3557
# Epoch 86/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3534 - mse: 1.3534
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3516 - mse: 1.3516
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3487 - mse: 1.3487
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3468 - mse: 1.3468
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3449 - mse: 1.3449
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3421 - mse: 1.3421
# Epoch 92/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3397 - mse: 1.3397
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3370 - mse: 1.3370
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3360 - mse: 1.3360
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3330 - mse: 1.3330
# Epoch 96/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3322 - mse: 1.3322
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3300 - mse: 1.3300
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3288 - mse: 1.3288
# Epoch 99/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3270 - mse: 1.3270
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3241 - mse: 1.3241
#
# Weights:
#
# [array([[-0.3139807]], dtype=float32), array([0.53276706], dtype=float32)]
# 2/2 [==============================] - 0s 3ms/step

# %% [markdown]
# # Retraçons les points et le droite obtenue :

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("Two classes", fontsize="small")
centers = [(-4, 2), (0, 0)]
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10,center_box=(-10.0, 10.0))

Xe = X1[:,0]
Xs = X1[:,1]

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.plot(liste_x,prediction,color = 'r')
model.summary()
plt.show()
plt.show()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Comment modifier le réseau de neurones pour séparer les 2 classes ?
#
# * Maintenant les données d'entrée sont de dimension 2, en entrée on met x et y c'est à dire X1
# * Le réseau comporte une seule couche d'entrée comportant un seul neurone. La fonction d'activation est la fonction sigmoide.
# * En sortie (output) on met la classe de Y1 dimension 1.

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=1,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))

#Création du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy']) # on compile mais on sauve l'historique d'apprentissage du réseau
# on pourra comme ça tracer les graphiques d'évolution des pertes et de la précision.

# entrée X1 de dimension 2 (x, y)
entree = X1
# sortie de dimension  1 (classe bipolaire)
sortie = Y1

#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100)

#Print weights
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire l'appartenance de points à un classe : 
#print(X1)
A= [[2,2]]
A_array = np.array(A)
B= [[-4,2]]
B_array = np.array(B)

#print(A[0][1]) # valeur x de A

print('prediction A :')
print(model.predict(A_array))
print('prédiction B :')
print(model.predict(B_array))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1923 - accuracy: 0.6900
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.7100
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.7100
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1646 - accuracy: 0.7400
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1577 - accuracy: 0.7600
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1513 - accuracy: 0.7600
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 0.7600
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1397 - accuracy: 0.7700
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.7700
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.7700
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1252 - accuracy: 0.7700
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.7800
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1165 - accuracy: 0.7900
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1126 - accuracy: 0.8000
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1088 - accuracy: 0.8200
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.8300
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.8400
# Epoch 18/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.8500
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0949 - accuracy: 0.8700
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.8700
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0884 - accuracy: 0.8800
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 0.9000
# Epoch 23/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0826 - accuracy: 0.9000
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9100
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9100
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9100
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0721 - accuracy: 0.9100
# Epoch 28/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9200
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9300
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9400
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9400
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0604 - accuracy: 0.9400
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9400
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0563 - accuracy: 0.9400
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 0.9400
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 0.9400
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0514 - accuracy: 0.9400
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0499 - accuracy: 0.9500
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9500
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9600
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 0.9600
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 0.9700
# Epoch 43/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9700
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9700
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9700
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9800
# Epoch 47/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9800
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9800
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9800
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 0.9800
# Epoch 51/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0350 - accuracy: 0.9800
# Epoch 52/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0342 - accuracy: 0.9800
# Epoch 53/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0335 - accuracy: 0.9800
# Epoch 54/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9800
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 0.9800
# Epoch 56/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 0.9800
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9800
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9800
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 0.9800
# Epoch 60/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 0.9800
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 0.9800
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9800
# Epoch 63/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9800
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9800
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9800
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 0.9800
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9800
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 0.9800
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0244 - accuracy: 0.9800
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9800
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9800
# Epoch 72/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0234 - accuracy: 0.9800
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9800
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9800
# Epoch 75/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0224 - accuracy: 0.9800
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9900
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9900
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9900
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9900
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9900
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9900
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9900
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9900
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9900
# Epoch 85/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9900
# Epoch 86/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 0.9900
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9900
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9900
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9900
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 0.9900
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9900
# Epoch 92/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9900
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9900
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9900
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9900
# Epoch 96/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9900
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9900
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9900
# Epoch 99/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9900
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9900
#
# Weights:
#
# [array([[ 1.0862904 ],
#        [-0.59575737]], dtype=float32), array([2.1793818], dtype=float32)]
# prediction A :
# 1/1 [==============================] - 0s 38ms/step
# [[0.9593184]]
# prédiction B :
# 1/1 [==============================] - 0s 19ms/step
# [[0.0336571]]

# %% [markdown]
# # Tracé des graphes avec deux points de tests : A et B

# %%
print('prediction A :')
print(model.predict(A))
print('prédiction B :')
print(model.predict(B))

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)

ax =plt.subplot(111)
plt.title("2 classes", fontsize="small")

#print(A)
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.scatter(A[0][0], A[0][1], marker="o",c='red', s=40, edgecolor="red")
plt.scatter(B[0][0], B[0][1], marker="o",c='blue', s=40, edgecolor="blue")

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
Ylim = (-xe*1.0792954 - 2.191928)/(-0.56038827)

plt.plot(xe,Ylim,color = 'r')
#model.summary()
plt.show()
# Out:
# prediction A :
# 1/1 [==============================] - 0s 46ms/step
# [[0.9593184]]
# prédiction B :
# 1/1 [==============================] - 0s 36ms/step
# [[0.0336571]]

# %% [markdown]
# # Visualisons l'évolution des erreurs et de la précision du modèle sur les données d'entrainement

# %%
# list all data in history

# Représentation d'un nuage de points

fig, ax1 = plt.subplots(figsize=(6, 4))
ax2 = ax1.twiny()

plt.title('modèle pertes et précision')
ax1.plot(history.history['loss'], 'g-', label = 'loss')
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()

ax2.plot(history.history['accuracy'], 'b-', label ='accuracy')
ax2.set_ylabel('accuracy')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Exemple avec 3 classes ...
#
# * Combien de neurones doit comporter la couche d'entrée pour obtenir un résultat convenable ?
# Essayer de modifier le nombre de neurones de la couche d'entrée....
# La couche de sortie doit comporter obligatoirement 3 neurones car on utilise la fonction d'activation softmax et il y a 3 classes

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.optimizers import SGD, Adam
from keras.utils import to_categorical
import numpy as np 
#from sklearn.cluster import kmeans_plusplus
from sklearn.datasets import make_blobs

# Generate sample data
n_samples = 4000
n_components = 3

X, y_true = make_blobs(
    n_samples=n_samples, centers=n_components, cluster_std=0.60, random_state=0
)

print('y_true :')
print(y_true)
#my_init = initializers.Zeros() 
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)

model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=128,input_shape=[2],activation= 'relu',kernel_initializer = my_init))
#La couche de sortie, units vaut 3 mais activation softmax
model.add(Dense(units=3, activation='softmax'))

#Optimisation du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='categorical_crossentropy',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  3 (3 classes)
sortie = to_categorical(y_true) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 0 0
# 1 >  1 0 0    vecteur (y_true) > matrice binaire (sortie)
# 2 >  0 1 0


#Entraînement du réseau ? passages
model.fit(x=entree,y=sortie,epochs=20,verbose =0)

#Print weights
#print("")
#print("Weights: \n")
#print(model.get_weights())

#Prediction
A= [[2,2.1]]
B= [[-2,3]]
C= [[0,3.2]]
Apred = model.predict(A)
Bpred = model.predict(B)
Cpred = model.predict(C)

#Affichage des prédictions
#print(model.predict(B))
#print(A[0][1])

print('prediction A :')
print(f"[{Apred[0][0]:.2f},{Apred[0][1]:.2f},{Apred[0][2]:.2f}]")

print('prédiction B :')
print(f"[{Bpred[0][0]:.2f},{Bpred[0][1]:.2f},{Bpred[0][2]:.2f}]")

print('prédiction C :')
print(f"[{Cpred[0][0]:.2f},{Cpred[0][1]:.2f},{Cpred[0][2]:.2f}]")

# Tracés des points avec les prédistions pour A, B et C
plt.figure(figsize=(8, 8))
plt.subplot(111)

#colors = ["#4EACC5", "#FF9C34", "#4E9A06"]
colors = ["red", "green", "blue"]

for k, col in enumerate(colors):# k index , col couleur
    cluster_data = (y_true == k)# cluster succession de valeurs vraies ou fausses
    plt.scatter(X[cluster_data, 0], X[cluster_data, 1], c=col, marker=".", s=10)# X[cluster_data, 0] prend les valeurs X[i,0] pour lesquelles cluster_data[i]=True
plt.scatter(A[0][0], A[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(B[0][0], B[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(C[0][0], C[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.text(2, 1.6, f"[{Apred[0][0]:.1f},{Apred[0][1]:.1f},{Apred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(-2, 2.6, f"[{Bpred[0][0]:.1f},{Bpred[0][1]:.1f},{Bpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(0, 3.5, f"[{Cpred[0][0]:.1f},{Cpred[0][1]:.1f},{Cpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')

plt.title("3 classes", fontsize="small")
plt.show()
# Out:
# y_true :
# [2 2 0 ... 0 2 1]
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 31ms/step
# prediction A :
# [0.00,1.00,0.00]
# prédiction B :
# [0.00,0.00,1.00]
# prédiction C :
# [0.66,0.00,0.34]

# %% [markdown]
# # Traçons les différents domaines ....

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, model, steps=200,alpha=0.2,seuil=0.45):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha),(0, 0, 1,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        bounds = [0, 0.5, 1]
        norm = mpl.colors.BoundaryNorm(bounds, cmap.N) 
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    
    for i in range(0,3): 
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.1f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    ax.scatter(X[:,0], X[:,1], c=y, lw=1,marker=".", s=10)
    
    return fig, ax

plot_decision_boundary2(entree, sortie, model, alpha=0.2)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.6)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.8)
# Out:
# 1250/1250 [==============================] - 1s 734us/step
# 1250/1250 [==============================] - 1s 744us/step
# 1250/1250 [==============================] - 1s 717us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)
