# %%
## space for importing required libraries
from sklearn.datasets import make_classification, make_circles #libraries to generate data
from sklearn import datasets
import matplotlib.pyplot as plt # importing library to plot
import numpy as np #numpy library for data manipulation and plotting

# %%
np.random.seed(0)
numPoints = 200
X, y = datasets.make_moons(numPoints, noise=0.10)

X = 10 * X

f, ax = plt.subplots(figsize=(8, 6)) #plotting data
ax.scatter(X[:,0],X[:,1], c=y, s=50,cmap="bwr")
plt.show()

# %% [markdown]
# # Création du réseau de neurones.
# ### Modifier le réseau ci-dessous pour le rendre plus performant

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
# Modifiez ici vos réseaux de neuronespour améliorer sa performance et donc séparer les 2 classes correctement.
model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=10,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))

#Couches intermédiaires

#La couche de sortie, units vaut 2 mais activation softmax
model.add(Dense(units=2, activation='softmax'))

#Optimiseur SGD ou adam ("adam "alternatif à "sgd")
#opt = SGD(learning_rate=0.01) #w = w - learning_rate * grad
opt = Adam(learning_rate=0.1)
model.compile(loss='binary_crossentropy',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  2 (2 classes)
sortie = to_categorical(y) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 1
# 1 >  1 0     vecteur (y_true) > matrice binaire (sortie)

#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100, batch_size=20)
print(f"précision obtenue : {history.history['accuracy'][-1]:.3f}")
model.predict([[0, 5],[1,9]])

# performance du réseau
# Représentation d'un nuage de points

fig, ax1 = plt.subplots(figsize=(6, 4))
ax2 = ax1.twiny()

plt.title('modèle pertes et précision')
ax1.plot(history.history['loss'], 'g-', label = 'loss')
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()

ax2.plot(history.history['accuracy'], 'b-', label ='accuracy')
ax2.set_ylabel('accuracy')
ax2.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6209 - accuracy: 0.7250
# Epoch 2/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3830 - accuracy: 0.8750
# Epoch 3/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3555 - accuracy: 0.8750
# Epoch 4/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3427 - accuracy: 0.8750
# Epoch 5/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3161 - accuracy: 0.8800
# Epoch 6/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3069 - accuracy: 0.8800
# Epoch 7/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2909 - accuracy: 0.8900
# Epoch 8/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2854 - accuracy: 0.8950
# Epoch 9/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2914 - accuracy: 0.8900
# Epoch 10/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2738 - accuracy: 0.9000
# Epoch 11/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2516 - accuracy: 0.8950
# Epoch 12/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2350 - accuracy: 0.9000
# Epoch 13/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.8950
# Epoch 14/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1990 - accuracy: 0.9350
# Epoch 15/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2038 - accuracy: 0.9300
# Epoch 16/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1890 - accuracy: 0.9300
# Epoch 17/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1857 - accuracy: 0.9500
# Epoch 18/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1674 - accuracy: 0.9400
# Epoch 19/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1528 - accuracy: 0.9450
# Epoch 20/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1621 - accuracy: 0.9450
# Epoch 21/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9400
# Epoch 22/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1592 - accuracy: 0.9500
# Epoch 23/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1756 - accuracy: 0.9450
# Epoch 24/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1623 - accuracy: 0.9500
# Epoch 25/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1491 - accuracy: 0.9500
# Epoch 26/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1410 - accuracy: 0.9550
# Epoch 27/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1417 - accuracy: 0.9450
# Epoch 28/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1322 - accuracy: 0.9550
# Epoch 29/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1582 - accuracy: 0.9500
# Epoch 30/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1818 - accuracy: 0.9300
# Epoch 31/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1429 - accuracy: 0.9600
# Epoch 32/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1319 - accuracy: 0.9500
# Epoch 33/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1408 - accuracy: 0.9350
# Epoch 34/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1219 - accuracy: 0.9500
# Epoch 35/100
# 10/10 [==============================] - 0s 991us/step - loss: 0.1197 - accuracy: 0.9400
# Epoch 36/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1116 - accuracy: 0.9550
# Epoch 37/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1054 - accuracy: 0.9600
# Epoch 38/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1024 - accuracy: 0.9400
# Epoch 39/100
# 10/10 [==============================] - 0s 963us/step - loss: 0.0990 - accuracy: 0.9600
# Epoch 40/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1052 - accuracy: 0.9500
# Epoch 41/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0864 - accuracy: 0.9850
# Epoch 42/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 0.9750
# Epoch 43/100
# 10/10 [==============================] - 0s 966us/step - loss: 0.0570 - accuracy: 0.9950
# Epoch 44/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0582 - accuracy: 0.9850
# Epoch 45/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0665 - accuracy: 0.9750
# Epoch 46/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0611 - accuracy: 0.9800
# Epoch 47/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0396 - accuracy: 0.9950
# Epoch 48/100
# 10/10 [==============================] - 0s 941us/step - loss: 0.0349 - accuracy: 0.9950
# Epoch 49/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 50/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0317 - accuracy: 0.9950
# Epoch 51/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0337 - accuracy: 0.9950
# Epoch 52/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0291 - accuracy: 0.9950
# Epoch 53/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0272 - accuracy: 0.9950
# Epoch 54/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0271 - accuracy: 0.9950
# Epoch 55/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0325 - accuracy: 0.9950
# Epoch 56/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 58/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0250 - accuracy: 0.9950
# Epoch 59/100
# 10/10 [==============================] - 0s 955us/step - loss: 0.0249 - accuracy: 0.9900
# Epoch 60/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0302 - accuracy: 0.9950
# Epoch 61/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9900
# Epoch 62/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0291 - accuracy: 0.9950
# Epoch 63/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0270 - accuracy: 0.9900
# Epoch 64/100
# 10/10 [==============================] - 0s 991us/step - loss: 0.0407 - accuracy: 0.9950
# Epoch 65/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0248 - accuracy: 0.9950
# Epoch 66/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0222 - accuracy: 0.9950
# Epoch 68/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 0.9950
# Epoch 69/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0296 - accuracy: 0.9950
# Epoch 70/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 0.9950
# Epoch 76/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 0s 946us/step - loss: 0.0165 - accuracy: 0.9950
# Epoch 81/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0157 - accuracy: 0.9950
# Epoch 83/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 0.9950
# Epoch 84/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.9950
# Epoch 85/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 0.9950
# Epoch 86/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 0.9950
# Epoch 88/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 0s 951us/step - loss: 0.0119 - accuracy: 0.9950
# Epoch 94/100
# 10/10 [==============================] - 0s 872us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.9950
# Epoch 98/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 0.9950
# Epoch 99/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 0s 942us/step - loss: 0.0168 - accuracy: 0.9950
# précision obtenue : 0.995
# 1/1 [==============================] - 0s 70ms/step

# %% [markdown]
# # Tracé des zones de prédiction

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, NbClasses, model, steps=250,alpha=0.4,seuil=0.51):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    steps = steps
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    #fig, ax = plt.subplots()
    
    for i in range(0,NbClasses): 
        #labels1= labels[:,i]
        #print(labels1)
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.2f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    #print(y)
    ax.scatter(X[:,0], X[:,1], c= y,lw=5,marker=".", s=50,cmap="RdBu")
    
    return fig, ax

plot_decision_boundary2(entree, sortie[:,0], 2, model, alpha=0.4, seuil=0.5)
#plot_decision_boundary2(entree, y, 2, model, alpha=0.2,seuil = 0.6)
#plot_decision_boundary2(entree, y, 2, model, alpha=0.2,seuil = 0.9)
# Out:
# 1954/1954 [==============================] - 1s 748us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)
